# %%
# !git clone https://github.com/universome/alis.git
# Out:
# Cloning into 'alis'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 145 (delta 51), reused 123 (delta 35), pack-reused 0
# Receiving objects: 100% (145/145), 7.08 MiB | 26.95 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
# !cd alis; python3 download_lhq.py lhq_256
# Out:
# Saving files into ./lhq/lhq_256 directory...
# ...
# J6bpmRyOJonT3VoXnDag%3D%3D%3A&limit=0&content_type=application%2Fzip&owner_uid=179435506&fsize=9335091163&hid=658cbf1cfcf7075ae6b1b31b597b7492&media_type=compressed&tknv=v2: 9.34GB [06:47, 22.9MB/s]

# %%
from PIL import Image
import os
import numpy as np

# %%
files = os.listdir("lhq_256")
print(len(files))
img_yuv = []
for i in files[:1]:
  print(i)
  img = Image.open("lhq_256/"+i)
  img_yuv.append(img.convert('YCbCr'))
# Out:
# 30093
# 0029407.png

# %%
np.array(img_yuv[0]).shape
# Out:
# (256, 256, 3)

# %%
class CustomDataGen(tf.keras.utils.Sequence):
    
    def __init__(self):
        
        self.batch_size = 1;
        

    def on_epoch_end(self):
      np.random.shuffle(files)
    
    def __getitem__(self, index):
        while 1:
          try:
            img = Image.open("lhq_256/"+files[index])
            break
          except:
            index+=1
          
        y = img.convert('YCbCr')
        x = y.convert('L')
        x = np.array(x).reshape((256, 256, 1)).astype(float)
        y = np.array(y).astype(float)
        return np.array([x]), np.array([y])
      

    
    def __len__(self):
        return len(files) // self.batch_size
trangen = CustomDataGen()

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model2 = tf.keras.models.Sequential([
  tf.keras.layers.Input(shape=(256, 256, 1)),
  tf.keras.layers.Conv2D(4,(3,3)),
  tf.keras.layers.MaxPool2D(3),
  tf.keras.layers.Conv2D(8,(3,3)),
  tf.keras.layers.MaxPool2D(3),
  tf.keras.layers.Conv2DTranspose(8,(3,3)),
  tf.keras.layers.UpSampling2D((2,2)),
  tf.keras.layers.Conv2DTranspose(4,(3,3)),
  tf.keras.layers.UpSampling2D((2,2)),
  tf.keras.layers.Conv2DTranspose(2,(3,3)),
  tf.keras.layers.UpSampling2D((2,2)),
  tf.keras.layers.Conv2DTranspose(1,(5,5)),
  tf.keras.layers.Conv2DTranspose(1,(5,5)),
  tf.keras.layers.Conv2DTranspose(3,(5,5)),

])
print(model.input_shape)
model2.summary()
model2.compile(optimizer=tf.keras.optimizers.Adam(),
          loss="mean_squared_error")
# Out:
# (None, 256, 256, 1)
# Model: "sequential_57"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_124 (Conv2D)          (None, 254, 254, 4)       40
# _________________________________________________________________
# max_pooling2d_118 (MaxPoolin (None, 84, 84, 4)         0
# _________________________________________________________________
# conv2d_125 (Conv2D)          (None, 82, 82, 8)         296
# _________________________________________________________________
# max_pooling2d_119 (MaxPoolin (None, 27, 27, 8)         0
# _________________________________________________________________
# conv2d_transpose_177 (Conv2D (None, 29, 29, 8)         584
# _________________________________________________________________
# up_sampling2d_102 (UpSamplin (None, 58, 58, 8)         0
# _________________________________________________________________
# ...

# %%
model2.fit(trangen, epochs=30)
# Out:
# Epoch 1/30
# 30093/30093 [==============================] - 245s 8ms/step - loss: 1680.6630
# Epoch 2/30
# 30093/30093 [==============================] - 241s 8ms/step - loss: 1326.7146
# Epoch 3/30
# 30093/30093 [==============================] - 246s 8ms/step - loss: 1242.5034
# Epoch 4/30
# 30093/30093 [==============================] - 247s 8ms/step - loss: 1158.4761
# Epoch 5/30
# 30093/30093 [==============================] - 248s 8ms/step - loss: 1072.2263
# Epoch 6/30
# 30093/30093 [==============================] - 247s 8ms/step - loss: 987.0894
# Epoch 7/30
# 30093/30093 [==============================] - 244s 8ms/step - loss: 907.9895
# Epoch 8/30
# 30093/30093 [==============================] - 243s 8ms/step - loss: 838.8004
# Epoch 9/30
# 30093/30093 [==============================] - 244s 8ms/step - loss: 781.7189
# Epoch 10/30
# 30093/30093 [==============================] - 244s 8ms/step - loss: 736.3598
# Epoch 11/30
# ...

# %%
model2.save("/drive/My Drive/mode2l.mm")
# Out:
# INFO:tensorflow:Assets written to: /drive/My Drive/mode2l.mm/assets

# %%
model.fit(trangen, epochs=30)
model.save("/drive/My Drive/model60.mm")

# %%
model.fit(trangen, epochs=30)
model.save("/drive/My Drive/model90.mm")

# %%
model.fit(trangen, epochs=30)
model.save("/drive/My Drive/model120.mm")

# %%
from matplotlib.pyplot import imshow
imshow(img_yuv[0].convert('L'),cmap='gray')
imshow(img_yuv[0])
np.array(img_yuv[0].convert('L')).shape
# np.array([np.array(img_yuv[0].convert('L'))]).reshape((1,256,256,1))
# Out:
# (256, 256)

# %%
imshow(trangen.__getitem__(1)[0].reshape(256,256),cmap='gray')

# %%
import time

# %%
  print("B-A-W")
  imshow(trangen.__getitem__(5)[0].reshape(256,256),cmap='gray')
# Out:
# B-A-W

# %%
  print("Ground Truth")
  imshow(trangen.__getitem__(15)[1].reshape(256,256,3)/np.array((255,255,255)))
# Out:
# Ground Truth

# %%
def result(i):
  print("Predicted")
  input = trangen.__getitem__(i)[0]
  res = model2.predict(input.reshape(1,256,256,1))
  print(np.array(Image.fromarray(trangen.__getitem__(i)[0].reshape(256,256)).convert('RGB')).shape)
  greylevel = np.array(Image.fromarray(trangen.__getitem__(i)[0].reshape(256,256)).convert('RGB'))
  imshow((res.reshape(256,256,3)+greylevel)/(256*2))

result(15)
# Out:
# Predicted
# (256, 256, 3)

# %%
type(np.random.rand(1,2,2,1))
# Out:
# numpy.ndarray
